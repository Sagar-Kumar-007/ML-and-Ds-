# %% [markdown]
# # Underfitting

# %%
from IPython.display import Image

# %%
Image(filename="underfit.png",width=500)

# %%
# You can see that the model should have been a curve but we have taken a linear model and hence there are many errors
# and our model becomes underfit.

# %% [markdown]
# # Overfitting

# %%
Image(filename="overfit.png",width=500)

# %%
# Using ML algorithms like random forests and XGBoost causes overfitting of model.

# %% [markdown]
# # Generalized Fitting:

# %%
# To overcome underfitting and overfitting, we use Generalized fitting. In Generalized fitting, we have errors both during
# training and testing. But the errors caused are very little when compared to underfitting and overfitting.

# %%
Image(filename="Generalizedfit.png",width=500)

# %% [markdown]
# # How To Avoid Underfitting and Overfitting

# %%
Image(filename="avoid over and under fitting.png",width=700)

# %%
# Regularization: Using Ridge and Lasso Regression.
# Dropout: When using neural network to train the model, we may overfit our data while using more no. of neurons.
         # To avoid this we reduce or drop some neurons.

# %%
# To know whether our model is underfit or overfit we use cross Validation.

# %%
# To be Continued...
